# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()

# %%
TOTAL_WHITE_POPULATION = 236.5e6
TOTAL_BLACK_POPULATION = 41.99E6
TOTAL_ASIAN_POPULATION = 18.64E6
TOTAL_AMERICAN_INDIAN_POPULATION = 2.708E6

# %%
df = pd.read_csv('./releasing_df.csv')

# %%
df.groupby('race').count()
# Out:
#                  Unnamed: 0  actRelDate    age  faclCode  faclName  faclType  \
# race
# American Indian         618           0    618       514       618       514
# Asian                   223           0    223       207       223       207
# Black                  6012           0   6012      5404      6012      5404
# White                 13577           0  13577     11639     13577     11639
#
#                  inmateNum  nameFirst  nameLast  nameMiddle  ...  releaseCode  \
# race                                                         ...
# American Indian        618        618       618         424  ...            0
# Asian                  223        223       223         110  ...            0
# Black                 6012       6012      6012        3087  ...            0
# White                13577      13577     13577        6861  ...            0
#
#                    sex  inmateId    lat    lng  address  state  orientation_y  \
# race
# ...

# %%
race_df = pd.DataFrame(
    [
        {
            'race': 'American Indian',
            'population': TOTAL_AMERICAN_INDIAN_POPULATION
        }, {
            'race': 'Asian',
            'population': TOTAL_ASIAN_POPULATION
        }, {
            'race': 'Black',
            'population': TOTAL_BLACK_POPULATION
        }, {
            'race': 'White',
            'population': TOTAL_WHITE_POPULATION
        }
    ]
)

# %%
rdf = rdf.merge(race_df, left_on='race', right_on='race')

# %%
rdf.set_index('race')
# Out:
#                  Unnamed: 0  actRelDate    age  faclCode  faclName  faclType  \
# race
# American Indian         618           0    618       514       618       514
# Asian                   223           0    223       207       223       207
# Black                  6012           0   6012      5404      6012      5404
# White                 13577           0  13577     11639     13577     11639
#
#                  inmateNum  nameFirst  nameLast  nameMiddle  ...  inmateId  \
# race                                                         ...
# American Indian        618        618       618         424  ...       618
# Asian                  223        223       223         110  ...       223
# Black                 6012       6012      6012        3087  ...      6012
# White                13577      13577     13577        6861  ...     13577
#
#                    lat    lng  address  state  orientation_y  orientation_x  \
# race
# ...

# %%
rdf['capita'] = rdf['inmateId'] / rdf['population']

# %%
rdf[['race', 'capita']]
# Out:
#               race    capita
# 0  American Indian  0.000228
# 1            Asian  0.000012
# 2            Black  0.000143
# 3            White  0.000057
